# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([17, 18, 19, 14, 44, 34, 10, 50, 2, 20])
y = np.array([0, 1, 1, 0, 1, 1, 0, 1, 0, 1])

len(X), len(y)
# Out:
# (10, 10)

# %%
# plot data


plt.figure(figsize = (15, 5))
plt.scatter(X, y, marker = 'x')

# %%
def compute_linear(X, w, b):

    return w * X + b

# %%
def compute_model(X, w, b):

    z = compute_linear(X, w, b)

    exp = np.exp(-z)

    g_z = 1 / ( 1 + exp)

    return g_z
